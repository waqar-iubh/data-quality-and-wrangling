# %%
# !pip install pandas numpy fuzzywuzzy python-Levenshtein
# Out:
# Requirement already satisfied: pandas in /home/waqar/anaconda3/lib/python3.11/site-packages (1.5.3)
# Requirement already satisfied: numpy in /home/waqar/anaconda3/lib/python3.11/site-packages (1.26.4)
# Requirement already satisfied: fuzzywuzzy in /home/waqar/anaconda3/lib/python3.11/site-packages (0.18.0)
# Requirement already satisfied: python-Levenshtein in /home/waqar/anaconda3/lib/python3.11/site-packages (0.27.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /home/waqar/anaconda3/lib/python3.11/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/waqar/anaconda3/lib/python3.11/site-packages (from pandas) (2022.7)
# Requirement already satisfied: Levenshtein==0.27.1 in /home/waqar/anaconda3/lib/python3.11/site-packages (from python-Levenshtein) (0.27.1)
# Requirement already satisfied: rapidfuzz<4.0.0,>=3.9.0 in /home/waqar/anaconda3/lib/python3.11/site-packages (from Levenshtein==0.27.1->python-Levenshtein) (3.12.2)
# Requirement already satisfied: six>=1.5 in /home/waqar/anaconda3/lib/python3.11/site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)

# %%
import pandas as pd
import numpy as np
from fuzzywuzzy import fuzz
from fuzzywuzzy import process
import re

# %% [markdown]
# # Load the Dataset

# %%
#Load CSV file into pandas

try:
    df = pd.read_csv('dataset.csv')
    print("Dataset loaded successfully!")
    print(f"Initial shape: {df.shape}")
except FileNotFoundError:
    print("Please provide the correct path to your CSV file")
# Out:
# Dataset loaded successfully!
# Initial shape: (27940, 26)

# %% [markdown]
# # Standardization of Job Titles using Fuzzy Matching

# %%
"""
Convert to lowercase and remove extra whitespace.
Remove special characters except basic punctuation
"""
def clean_text(text):
    if pd.isna(text):
        return text
    text = str(text).lower().strip()
    text = re.sub(r'[^\w\s.,-]', '', text)
    return text

# %%
"""
Standardize job titles using fuzzy matching
threshold: similarity score threshold (0-100)
"""
def standardize_job_titles(df, column_name, threshold=50):
    # Clean the job titles first
    df[column_name] = df[column_name].apply(clean_text)
    print(f"Starting standardization of '{column_name}' column...")
    
    # Get unique job titles
    unique_titles = df[column_name].dropna().unique()
    print(f"Found {len(unique_titles)} unique job titles to process")
    
    # Create clusters of similar titles
    standardized_titles = {}
    remaining_titles = list(unique_titles)
    total_clusters = 0
    
    while remaining_titles:
        base_title = remaining_titles.pop(0)
        print(f"\nProcessing base title: '{base_title}'")
        matches = process.extract(base_title, remaining_titles, 
                               scorer=fuzz.token_sort_ratio)
        
        # Find similar titles above threshold
        similar_titles = [m[0] for m in matches if m[1] >= threshold]
        
        if similar_titles:
            total_clusters += 1
            print(f"Found {len(similar_titles)} similar titles (threshold={threshold}):")
            for match, score in [(m[0], m[1]) for m in matches if m[1] >= threshold]:
                print(f"  - '{match}' (similarity score: {score}) -> standardized to '{base_title}'")
            standardized_titles[base_title] = similar_titles
            # Remove matched titles from remaining list
            remaining_titles = [t for t in remaining_titles if t not in similar_titles]
            print(f"Remaining titles to process: {len(remaining_titles)}")
        else:
            print("  No matches found above threshold")
    
    # Create mapping dictionary
    title_mapping = {}
    for standard_title, similar_list in standardized_titles.items():
        title_mapping[standard_title] = standard_title
        for similar in similar_list:
            title_mapping[similar] = standard_title
    
    # Apply mapping to dataframe
    print(f"\nApplying {len(title_mapping)} mappings to the dataset...")
    df[f'standardized_{column_name}'] = df[column_name].map(
        lambda x: title_mapping.get(x, x) if pd.notna(x) else x
    )
    
    # Summary
    print(f"Standardization complete!")
    print(f"Total clusters formed: {total_clusters}")
    print(f"Unique titles reduced from {len(unique_titles)} to {df[f'standardized_{column_name}'].nunique()}")
    
    return df, title_mapping

# %%
"""
Apply Standardization
"""
def apply_standardization(df):
    job_column = 'Job title'
    
    # Initial data exploration
    print("Initial unique job titles:", df[job_column].nunique())
    print("Missing values:", df[job_column].isna().sum())
    
    # Apply fuzzy matching for remaining titles
    df, title_mapping = standardize_job_titles(df, f'{job_column}')
    
    return df

try:
    # Process the data
    processed_df = apply_standardization(df)
    
    # Display sample of results
    print("\nSample of processed data:")
    print(processed_df[[
        'Job title',
        'standardized_Job title'
    ]].head(10))

except Exception as e:
    print(f"An error occurred: {str(e)}")
# Out:
# Initial unique job titles: 14288
# Missing values: 0
# Starting standardization of 'Job title' column...
# Found 12062 unique job titles to process
#
# Processing base title: 'research and instruction librarian'
# Found 5 similar titles (threshold=50):
#   - 'research  instruction librarian' (similarity score: 94) -> standardized to 'research and instruction librarian'
#   - 'reference and instruction librarian' (similarity score: 90) -> standardized to 'research and instruction librarian'
#   - 'head of research and instruction' (similarity score: 76) -> standardized to 'research and instruction librarian'
#   - 'instruction librarian' (similarity score: 76) -> standardized to 'research and instruction librarian'
#   - 'professor  instruction and assessment librarian' (similarity score: 75) -> standardized to 'research and instruction librarian'
# Remaining titles to process: 12056
#
# Processing base title: 'change  internal communications manager'
# Found 5 similar titles (threshold=50):
#   - 'internal communications manager' (similarity score: 90) -> standardized to 'change  internal communications manager'
#   - 'senior manager, internal communications' (similarity score: 82) -> standardized to 'change  internal communications manager'
#   - 'internal communications and engagement manager' (similarity score: 81) -> standardized to 'change  internal communications manager'
#   - 'digital communications manager' (similarity score: 79) -> standardized to 'change  internal communications manager'
#   - 'digital communications and web manager' (similarity score: 79) -> standardized to 'change  internal communications manager'
# Remaining titles to process: 12050
#
# Processing base title: 'marketing specialist'
# Found 5 similar titles (threshold=50):
#   - 'sr. marketing specialist' (similarity score: 93) -> standardized to 'marketing specialist'
#   - 'email marketing specialist' (similarity score: 87) -> standardized to 'marketing specialist'
#   - 'field marketing specialist' (similarity score: 87) -> standardized to 'marketing specialist'
#   - 'senior marketing specialist' (similarity score: 85) -> standardized to 'marketing specialist'
#   - 'events marketing specialist' (similarity score: 85) -> standardized to 'marketing specialist'
# Remaining titles to process: 12044
#
# Processing base title: 'program manager'
# Found 5 similar titles (threshold=50):
#   - 'programs manager' (similarity score: 97) -> standardized to 'program manager'
#   - 'programme manager' (similarity score: 94) -> standardized to 'program manager'
#   - 'program manager 2' (similarity score: 94) -> standardized to 'program manager'
#   - 'sr. program manager' (similarity score: 91) -> standardized to 'program manager'
#   - 'program manager ii' (similarity score: 91) -> standardized to 'program manager'
# Remaining titles to process: 12038
#
# Processing base title: 'accounting manager'
# Found 5 similar titles (threshold=50):
#   - 'it  accounting manager' (similarity score: 92) -> standardized to 'accounting manager'
#   - 'account manager' (similarity score: 91) -> standardized to 'accounting manager'
#   - 'accounts manager' (similarity score: 88) -> standardized to 'accounting manager'
#   - 'plant accounting manager' (similarity score: 86) -> standardized to 'accounting manager'
#   - 'client account manager' (similarity score: 85) -> standardized to 'accounting manager'
# Remaining titles to process: 12032
#
# Processing base title: 'scholarly publishing librarian'
# Found 5 similar titles (threshold=50):
#   - 'public librarian' (similarity score: 70) -> standardized to 'scholarly publishing librarian'
#   - 'school librarian' (similarity score: 65) -> standardized to 'scholarly publishing librarian'
#   - 'public services librarian' (similarity score: 65) -> standardized to 'scholarly publishing librarian'
#   - 'middle school librarian' (similarity score: 64) -> standardized to 'scholarly publishing librarian'
#   - 'senior publishing editor' (similarity score: 63) -> standardized to 'scholarly publishing librarian'
# Remaining titles to process: 12026
#
# Processing base title: 'publishing assistant'
# Found 5 similar titles (threshold=50):
#   - 'purchasing assistant' (similarity score: 80) -> standardized to 'publishing assistant'
#   - 'planning assistant' (similarity score: 79) -> standardized to 'publishing assistant'
#   - 'buying assistant' (similarity score: 78) -> standardized to 'publishing assistant'
#   - 'lending assistant' (similarity score: 76) -> standardized to 'publishing assistant'
#   - 'recruiting assistant' (similarity score: 75) -> standardized to 'publishing assistant'
# Remaining titles to process: 12020
#
# Processing base title: 'librarian'
# Found 5 similar titles (threshold=50):
#   - 'libraran' (similarity score: 94) -> standardized to 'librarian'
#   - 'librarian i' (similarity score: 90) -> standardized to 'librarian'
#   - 'librarian 4' (similarity score: 90) -> standardized to 'librarian'
#   - 'librarian 1' (similarity score: 90) -> standardized to 'librarian'
#   - 'librarian 2' (similarity score: 90) -> standardized to 'librarian'
# Remaining titles to process: 12014
#
# Processing base title: 'systems analyst'
# Found 5 similar titles (threshold=50):
#   - 'system analyst' (similarity score: 97) -> standardized to 'systems analyst'
#   - 'hr systems analyst' (similarity score: 91) -> standardized to 'systems analyst'
#   - 'it systems analyst' (similarity score: 91) -> standardized to 'systems analyst'
#   - 'systems analyst iv' (similarity score: 91) -> standardized to 'systems analyst'
#   - 'data  systems analyst' (similarity score: 86) -> standardized to 'systems analyst'
# Remaining titles to process: 12008
#
# Processing base title: 'senior accountant'
# Found 5 similar titles (threshold=50):
#   - 'senior tax accountant' (similarity score: 89) -> standardized to 'senior accountant'
#   - 'senior accountant cpa' (similarity score: 89) -> standardized to 'senior accountant'
#   - 'accounts senior' (similarity score: 88) -> standardized to 'senior accountant'
#   - 'junior accountant' (similarity score: 88) -> standardized to 'senior accountant'
#   - 'sr. accountant' (similarity score: 87) -> standardized to 'senior accountant'
# Remaining titles to process: 12002
#
# Processing base title: 'office manager'
# Found 5 similar titles (threshold=50):
#   - 'officer manager' (similarity score: 97) -> standardized to 'office manager'
#   - 'office manger' (similarity score: 96) -> standardized to 'office manager'
#   - 'office managet' (similarity score: 93) -> standardized to 'office manager'
#   - 'office managercoo' (similarity score: 90) -> standardized to 'office manager'
#   - 'box office manager' (similarity score: 88) -> standardized to 'office manager'
# Remaining titles to process: 11996
#
# Processing base title: 'deputy title ix coordinator assistant director office of equity and diversity'
# Found 5 similar titles (threshold=50):
#   - 'director, deputy chief conflict of interest officer, assistant professor' (similarity score: 65) -> standardized to 'deputy title ix coordinator assistant director office of equity and diversity'
#   - 'assistant directoradult svcs coordinator' (similarity score: 60) -> standardized to 'deputy title ix coordinator assistant director office of equity and diversity'
#   - 'executive assistant office of president and cfo' (similarity score: 60) -> standardized to 'deputy title ix coordinator assistant director office of equity and diversity'
#   - 'executive assistant to the executive director of development' (similarity score: 57) -> standardized to 'deputy title ix coordinator assistant director office of equity and diversity'
#   - 'communications coordinator  deputy public information officer' (similarity score: 57) -> standardized to 'deputy title ix coordinator assistant director office of equity and diversity'
# Remaining titles to process: 11990
#
# Processing base title: 'manager of information services'
# Found 5 similar titles (threshold=50):
#   - 'manager of education services' (similarity score: 83) -> standardized to 'manager of information services'
#   - 'manager information security' (similarity score: 81) -> standardized to 'manager of information services'
#   - 'information security manager' (similarity score: 81) -> standardized to 'manager of information services'
#   - 'manager, information security' (similarity score: 81) -> standardized to 'manager of information services'
#   - 'manager of client services' (similarity score: 81) -> standardized to 'manager of information services'
# Remaining titles to process: 11984
#
# Processing base title: 'legal aid staff attorney'
# Found 5 similar titles (threshold=50):
#   - 'attorney, legal aid' (similarity score: 86) -> standardized to 'legal aid staff attorney'
#   - 'staff attorney' (similarity score: 74) -> standardized to 'legal aid staff attorney'
#   - 'judicial staff attorney' (similarity score: 72) -> standardized to 'legal aid staff attorney'
#   - 'senior staff attorney' (similarity score: 71) -> standardized to 'legal aid staff attorney'
#   - 'staff attorney iii' (similarity score: 71) -> standardized to 'legal aid staff attorney'
# Remaining titles to process: 11978
#
# Processing base title: 'patient care coordinator'
# Found 5 similar titles (threshold=50):
#   - 'rn patient care coordinator' (similarity score: 94) -> standardized to 'patient care coordinator'
#   - 'patient coordinator' (similarity score: 88) -> standardized to 'patient care coordinator'
#   - 'care coordinator ii' (similarity score: 84) -> standardized to 'patient care coordinator'
#   - 'care coordinatorassistant' (similarity score: 82) -> standardized to 'patient care coordinator'
#   - 'quarantine care team coordinator' (similarity score: 79) -> standardized to 'patient care coordinator'
# Remaining titles to process: 11972
#
# Processing base title: 'quality and compliance specialist'
# Found 5 similar titles (threshold=50):
#   - 'qa specialist- compliance and quality' (similarity score: 96) -> standardized to 'quality and compliance specialist'
#   - 'regulatory compliance specialist' (similarity score: 80) -> standardized to 'quality and compliance specialist'
#   - 'online content quality specialist' (similarity score: 79) -> standardized to 'quality and compliance specialist'
#   - 'quality assurance specialist' (similarity score: 79) -> standardized to 'quality and compliance specialist'
#   - 'dot compliance specialist' (similarity score: 79) -> standardized to 'quality and compliance specialist'
# Remaining titles to process: 11966
#
# Processing base title: 'executive assistant'
# Found 5 similar titles (threshold=50):
#   - 'sr. executive assistant' (similarity score: 93) -> standardized to 'executive assistant'
#   - 'sr executive assistant' (similarity score: 93) -> standardized to 'executive assistant'
#   - 'executive assistant ii' (similarity score: 93) -> standardized to 'executive assistant'
#   - 'executive assistant iii' (similarity score: 90) -> standardized to 'executive assistant'
#   - 'executive assistant - svp' (similarity score: 90) -> standardized to 'executive assistant'
# Remaining titles to process: 11960
#
# Processing base title: 'graphic designer'
# Found 5 similar titles (threshold=50):
#   - 'graphic desinger' (similarity score: 94) -> standardized to 'graphic designer'
#   - 'graphic designer 1' (similarity score: 94) -> standardized to 'graphic designer'
#   - 'graphic design' (similarity score: 93) -> standardized to 'graphic designer'
#   - 'sr. graphic designer' (similarity score: 91) -> standardized to 'graphic designer'
#   - 'graphicsui designer' (similarity score: 91) -> standardized to 'graphic designer'
# Remaining titles to process: 11954
#
# Processing base title: 'senior manager'
# Found 5 similar titles (threshold=50):
#   - 'senior it manager' (similarity score: 90) -> standardized to 'senior manager'
#   - 'senior manager, it' (similarity score: 90) -> standardized to 'senior manager'
#   - 'senior manager, hr' (similarity score: 90) -> standardized to 'senior manager'
#   - 'senior hr manager' (similarity score: 90) -> standardized to 'senior manager'
#   - 'hr senior manager' (similarity score: 90) -> standardized to 'senior manager'
# Remaining titles to process: 11948
#
# Processing base title: 'assistant director of academic advising'
# Found 5 similar titles (threshold=50):
#   - 'assistant director, academic  advising' (similarity score: 96) -> standardized to 'assistant director of academic advising'
#   - 'director of academic advising' (similarity score: 85) -> standardized to 'assistant director of academic advising'
#   - 'assistant director of admission' (similarity score: 83) -> standardized to 'assistant director of academic advising'
#   - 'assistant director of admissions' (similarity score: 82) -> standardized to 'assistant director of academic advising'
#   - 'associate director of academics' (similarity score: 80) -> standardized to 'assistant director of academic advising'
# Remaining titles to process: 11942
#
# Processing base title: 'data programmer analyst'
# Found 5 similar titles (threshold=50):
#   - 'programmer analyst' (similarity score: 88) -> standardized to 'data programmer analyst'
#   - 'analyst programmer' (similarity score: 88) -> standardized to 'data programmer analyst'
#   - 'programmer analyst 2' (similarity score: 84) -> standardized to 'data programmer analyst'
#   - 'gis programmer  analyst' (similarity score: 84) -> standardized to 'data programmer analyst'
#   - 'gis programmer analyst' (similarity score: 84) -> standardized to 'data programmer analyst'
# Remaining titles to process: 11936
#
# Processing base title: 'program coordinator  assistant editor'
# Found 5 similar titles (threshold=50):
#   - 'assistant program director' (similarity score: 81) -> standardized to 'program coordinator  assistant editor'
#   - 'assistant technology coordinator' (similarity score: 76) -> standardized to 'program coordinator  assistant editor'
#   - 'associate professor and program coordinator' (similarity score: 76) -> standardized to 'program coordinator  assistant editor'
#   - 'asst. program director  volunteer coordinator' (similarity score: 76) -> standardized to 'program coordinator  assistant editor'
#   - 'conservation program assistant' (similarity score: 76) -> standardized to 'program coordinator  assistant editor'
# Remaining titles to process: 11930
#
# Processing base title: 'event planner'
# Found 5 similar titles (threshold=50):
#   - 'senior event planner' (similarity score: 79) -> standardized to 'event planner'
#   - 'event manager' (similarity score: 77) -> standardized to 'event planner'
#   - 'environmental planner' (similarity score: 76) -> standardized to 'event planner'
#   - 'senior events planner' (similarity score: 76) -> standardized to 'event planner'
#   - 'events manager' (similarity score: 74) -> standardized to 'event planner'
# Remaining titles to process: 11924
#
# Processing base title: 'researcher'
# Found 5 similar titles (threshold=50):
#   - 'researcher 3' (similarity score: 91) -> standardized to 'researcher'
#   - 'research' (similarity score: 89) -> standardized to 'researcher'
#   - 'ux researcher' (similarity score: 87) -> standardized to 'researcher'
#   - 'researcher iii' (similarity score: 83) -> standardized to 'researcher'
#   - 'user researcher' (similarity score: 80) -> standardized to 'researcher'
# Remaining titles to process: 11918
#
# Processing base title: 'teen librarian'
# Found 5 similar titles (threshold=50):
#   - 'teen librarian 1' (similarity score: 93) -> standardized to 'teen librarian'
#   - 'teacher librarian' (similarity score: 84) -> standardized to 'teen librarian'
#   - 'teacher-librarian' (similarity score: 84) -> standardized to 'teen librarian'
#   - 'senior librarian' (similarity score: 80) -> standardized to 'teen librarian'
#   - 'reference librarian' (similarity score: 79) -> standardized to 'teen librarian'
# Remaining titles to process: 11912
#
# Processing base title: 'communications specialist'
# Found 5 similar titles (threshold=50):
#   - 'communication specialist' (similarity score: 98) -> standardized to 'communications specialist'
#   - 'comminications specialist' (similarity score: 96) -> standardized to 'communications specialist'
#   - 'communications specialist i' (similarity score: 96) -> standardized to 'communications specialist'
#   - 'sr. communications specialist' (similarity score: 94) -> standardized to 'communications specialist'
#   - 'sr communications specialist' (similarity score: 94) -> standardized to 'communications specialist'
# Remaining titles to process: 11906
#
# Processing base title: 'program director'
# Found 5 similar titles (threshold=50):
#   - 'programs director' (similarity score: 97) -> standardized to 'program director'
#   - 'programme director' (similarity score: 94) -> standardized to 'program director'
#   - 'it program director' (similarity score: 91) -> standardized to 'program director'
#   - 'director of program' (similarity score: 91) -> standardized to 'program director'
#   - 'director of programs' (similarity score: 89) -> standardized to 'program director'
# Remaining titles to process: 11900
#
# Processing base title: 'bookkeeperbilling manager'
# Found 5 similar titles (threshold=50):
#   - 'bookkeeperhr manager' (similarity score: 80) -> standardized to 'bookkeeperbilling manager'
#   - 'bookkeeperoffice manager' (similarity score: 78) -> standardized to 'bookkeeperbilling manager'
#   - 'billing manager' (similarity score: 75) -> standardized to 'bookkeeperbilling manager'
#   - 'office manager  bookkeeper' (similarity score: 72) -> standardized to 'bookkeeperbilling manager'
#   - 'bookkeeping merchandiser' (similarity score: 69) -> standardized to 'bookkeeperbilling manager'
# Remaining titles to process: 11894
#
# Processing base title: 'economist'
# Found 5 similar titles (threshold=50):
#   - 'ecologist' (similarity score: 78) -> standardized to 'economist'
#   - 'agronomist' (similarity score: 74) -> standardized to 'economist'
#   - 'taxonomist' (similarity score: 74) -> standardized to 'economist'
#   - 'senior economist' (similarity score: 72) -> standardized to 'economist'
#   - 'receptionist' (similarity score: 67) -> standardized to 'economist'
# Remaining titles to process: 11888
#
# Processing base title: 'research engineer'
# Found 5 similar titles (threshold=50):
#   - 'research civil engineer' (similarity score: 85) -> standardized to 'research engineer'
#   - 'research intern' (similarity score: 81) -> standardized to 'research engineer'
#   - 'reservoir engineer' (similarity score: 80) -> standardized to 'research engineer'
#   - 'research manager' (similarity score: 79) -> standardized to 'research engineer'
#   - 'sr engineer' (similarity score: 79) -> standardized to 'research engineer'
# Remaining titles to process: 11882
#
# Processing base title: 'volunteer and giving coordinator'
# Found 5 similar titles (threshold=50):
#   - 'volunteer coordinator' (similarity score: 79) -> standardized to 'volunteer and giving coordinator'
#   - 'visitor services and volunteer coordinator' (similarity score: 78) -> standardized to 'volunteer and giving coordinator'
#   - 'hospice volunteer coordinator' (similarity score: 75) -> standardized to 'volunteer and giving coordinator'
#   - 'volunteer engagement coordinator' (similarity score: 75) -> standardized to 'volunteer and giving coordinator'
#   - 'member and donor coordinator' (similarity score: 70) -> standardized to 'volunteer and giving coordinator'
# Remaining titles to process: 11876
#
# Processing base title: 'editor'
# Found 5 similar titles (threshold=50):
#   - 'mediator' (similarity score: 86) -> standardized to 'editor'
#   - 'editor ii' (similarity score: 80) -> standardized to 'editor'
#   - 'auditor' (similarity score: 77) -> standardized to 'editor'
#   - 'web editor' (similarity score: 75) -> standardized to 'editor'
#   - 'copyeditor' (similarity score: 75) -> standardized to 'editor'
# Remaining titles to process: 11870
#
# Processing base title: 'financial advisor'
# Found 5 similar titles (threshold=50):
#   - 'financial aid advisor' (similarity score: 89) -> standardized to 'financial advisor'
#   - 'senior financial advisor' (similarity score: 83) -> standardized to 'financial advisor'
#   - 'financial administrator' (similarity score: 80) -> standardized to 'financial advisor'
#   - 'director, financial aid' (similarity score: 77) -> standardized to 'financial advisor'
#   - 'associate financial advisor' (similarity score: 77) -> standardized to 'financial advisor'
# Remaining titles to process: 11864
#
# Processing base title: 'administrative and hr manager'
# Found 5 similar titles (threshold=50):
#   - 'administrative manager' (similarity score: 86) -> standardized to 'administrative and hr manager'
#   - 'administrative manager for education' (similarity score: 83) -> standardized to 'administrative and hr manager'
#   - 'administration manager' (similarity score: 82) -> standardized to 'administrative and hr manager'
#   - 'finance and administration manager' (similarity score: 79) -> standardized to 'administrative and hr manager'
#   - 'manager of administration' (similarity score: 78) -> standardized to 'administrative and hr manager'
# Remaining titles to process: 11858
#
# Processing base title: 'senior irb analyst'
# Found 5 similar titles (threshold=50):
#   - 'senior it analyst' (similarity score: 91) -> standardized to 'senior irb analyst'
#   - 'senior bi analyst' (similarity score: 91) -> standardized to 'senior irb analyst'
#   - 'senior hr analyst' (similarity score: 91) -> standardized to 'senior irb analyst'
#   - 'senior gis analyst' (similarity score: 89) -> standardized to 'senior irb analyst'
#   - 'senior bsa analyst' (similarity score: 89) -> standardized to 'senior irb analyst'
# Remaining titles to process: 11852
#
# Processing base title: 'reporter'
# Found 5 similar titles (threshold=50):
#   - 'court reporter' (similarity score: 73) -> standardized to 'reporter'
#   - 'webtv reporter' (similarity score: 73) -> standardized to 'reporter'
#   - 'recruiter' (similarity score: 71) -> standardized to 'reporter'
#   - 'sports reporter' (similarity score: 70) -> standardized to 'reporter'
#   - 'senior reporter' (similarity score: 70) -> standardized to 'reporter'
# Remaining titles to process: 11846
#
# Processing base title: 'senior administrator'
# Found 5 similar titles (threshold=50):
#   - 'senior it administrator' (similarity score: 93) -> standardized to 'senior administrator'
#   - 'pension administrator' (similarity score: 88) -> standardized to 'senior administrator'
#   - 'irb administrator' (similarity score: 86) -> standardized to 'senior administrator'
#   - 'senior grants administrator' (similarity score: 85) -> standardized to 'senior administrator'
#   - 'senior system administrator' (similarity score: 85) -> standardized to 'senior administrator'
# Remaining titles to process: 11840
#
# Processing base title: 'staff services manager ii'
# Found 5 similar titles (threshold=50):
#   - 'it services manager' (similarity score: 82) -> standardized to 'staff services manager ii'
#   - 'it service manager' (similarity score: 79) -> standardized to 'staff services manager ii'
#   - 'digital services manager' (similarity score: 78) -> standardized to 'staff services manager ii'
#   - 'visitor services manager' (similarity score: 78) -> standardized to 'staff services manager ii'
#   - 'services manager' (similarity score: 78) -> standardized to 'staff services manager ii'
# Remaining titles to process: 11834
#
# Processing base title: 'lead engineer'
# Found 5 similar titles (threshold=50):
#   - 'engineering lead' (similarity score: 90) -> standardized to 'lead engineer'
#   - 'lead qa engineer' (similarity score: 90) -> standardized to 'lead engineer'
#   - 'lead web engineer' (similarity score: 87) -> standardized to 'lead engineer'
#   - 'lead ios engineer' (similarity score: 87) -> standardized to 'lead engineer'
#   - 'lead data engineer' (similarity score: 84) -> standardized to 'lead engineer'
# Remaining titles to process: 11828
#
# Processing base title: 'senior copywriter'
# Found 5 similar titles (threshold=50):
#   - 'junior copywriter' (similarity score: 88) -> standardized to 'senior copywriter'
#   - 'editor, copywriter' (similarity score: 88) -> standardized to 'senior copywriter'
#   - 'sr copywriter' (similarity score: 87) -> standardized to 'senior copywriter'
#   - 'senior copyeditor' (similarity score: 82) -> standardized to 'senior copywriter'
#   - 'senior recruiter' (similarity score: 79) -> standardized to 'senior copywriter'
# Remaining titles to process: 11822
#
# Processing base title: 'manager of data integrity and prospect research'
# Found 5 similar titles (threshold=50):
#   - 'manager of market research and data' (similarity score: 71) -> standardized to 'manager of data integrity and prospect research'
#   - 'research integrity manager' (similarity score: 71) -> standardized to 'manager of data integrity and prospect research'
#   - 'research project manager ii' (similarity score: 70) -> standardized to 'manager of data integrity and prospect research'
#   - 'clinical research project manager' (similarity score: 68) -> standardized to 'manager of data integrity and prospect research'
#   - 'assistant director of prospect research' (similarity score: 67) -> standardized to 'manager of data integrity and prospect research'
# Remaining titles to process: 11816
#
# Processing base title: 'principal software engineer'
# Found 5 similar titles (threshold=50):
#   - 'principle software engineer' (similarity score: 96) -> standardized to 'principal software engineer'
#   - 'principal software enginner' (similarity score: 96) -> standardized to 'principal software engineer'
#   - 'software engineer principal ii' (similarity score: 95) -> standardized to 'principal software engineer'
#   - 'principal ios software engineer' (similarity score: 93) -> standardized to 'principal software engineer'
#   - 'senior principal software engineer' (similarity score: 89) -> standardized to 'principal software engineer'
# Remaining titles to process: 11810
#
# Processing base title: 'intelligence analyst'
# Found 5 similar titles (threshold=50):
#   - 'senior intelligence analyst' (similarity score: 85) -> standardized to 'intelligence analyst'
#   - 'market intelligence analyst' (similarity score: 85) -> standardized to 'intelligence analyst'
#   - 'threat intelligence analyst' (similarity score: 85) -> standardized to 'intelligence analyst'
#   - 'business intelligence analyst' (similarity score: 82) -> standardized to 'intelligence analyst'
#   - 'all source intelligence analyst' (similarity score: 78) -> standardized to 'intelligence analyst'
# Remaining titles to process: 11804
#
# Processing base title: 'project manager'
# Found 5 similar titles (threshold=50):
#   - 'project manaager' (similarity score: 97) -> standardized to 'project manager'
#   - 'projekt manager' (similarity score: 93) -> standardized to 'project manager'
#   - 'sr. project manager' (similarity score: 91) -> standardized to 'project manager'
#   - 'it project manager' (similarity score: 91) -> standardized to 'project manager'
#   - 'project manager ii' (similarity score: 91) -> standardized to 'project manager'
# Remaining titles to process: 11798
#
# Processing base title: 'mobile developer'
# Found 5 similar titles (threshold=50):
#   - 'email developer' (similarity score: 84) -> standardized to 'mobile developer'
#   - 'senior mobile developer' (similarity score: 82) -> standardized to 'mobile developer'
#   - 'lead developer' (similarity score: 80) -> standardized to 'mobile developer'
#   - 'game developer' (similarity score: 80) -> standardized to 'mobile developer'
#   - 'developer ii' (similarity score: 79) -> standardized to 'mobile developer'
# Remaining titles to process: 11792
#
# Processing base title: 'product design director'
# Found 5 similar titles (threshold=50):
#   - 'director product design' (similarity score: 100) -> standardized to 'product design director'
#   - 'director of product design' (similarity score: 94) -> standardized to 'product design director'
#   - 'design director, ux' (similarity score: 83) -> standardized to 'product design director'
#   - 'director ux design' (similarity score: 83) -> standardized to 'product design director'
#   - 'sr director, design' (similarity score: 83) -> standardized to 'product design director'
# Remaining titles to process: 11786
#
# Processing base title: 'engineering specialist'
# Found 5 similar titles (threshold=50):
#   - 'energy specialist' (similarity score: 82) -> standardized to 'engineering specialist'
#   - 'elearning specialist' (similarity score: 81) -> standardized to 'engineering specialist'
#   - 'instrument specialist engineer' (similarity score: 81) -> standardized to 'engineering specialist'
#   - 'structural engineering specialist' (similarity score: 80) -> standardized to 'engineering specialist'
#   - 'engagement specialist' (similarity score: 79) -> standardized to 'engineering specialist'
# Remaining titles to process: 11780
#
# Processing base title: 'manager, total rewards'
# Found 5 similar titles (threshold=50):
#   - 'total rewards manager' (similarity score: 100) -> standardized to 'manager, total rewards'
#   - 'senior hr  total rewards manager' (similarity score: 81) -> standardized to 'manager, total rewards'
#   - 'senior reward manager' (similarity score: 76) -> standardized to 'manager, total rewards'
#   - 'retail manager' (similarity score: 74) -> standardized to 'manager, total rewards'
#   - 'records manager' (similarity score: 72) -> standardized to 'manager, total rewards'
# Remaining titles to process: 11774
#
# Processing base title: 'research and development engineer 3'
# Found 5 similar titles (threshold=50):
#   - 'research and development engineer' (similarity score: 97) -> standardized to 'research and development engineer 3'
#   - 'research and development engineer i' (similarity score: 94) -> standardized to 'research and development engineer 3'
#   - 'research and development manager' (similarity score: 87) -> standardized to 'research and development engineer 3'
#   - 'senior research  development engineer' (similarity score: 82) -> standardized to 'research and development engineer 3'
#   - 'director of research and development' (similarity score: 79) -> standardized to 'research and development engineer 3'
# Remaining titles to process: 11768
#
# Processing base title: 'science teacher public high school'
# Found 5 similar titles (threshold=50):
#   - 'high school science teacher' (similarity score: 89) -> standardized to 'science teacher public high school'
#   - 'science and humanities teacher high school' (similarity score: 79) -> standardized to 'science teacher public high school'
#   - 'lower school science teacher' (similarity score: 77) -> standardized to 'science teacher public high school'
#   - 'public school teacher' (similarity score: 76) -> standardized to 'science teacher public high school'
#   - 'teacher-public school, suburb' (similarity score: 74) -> standardized to 'science teacher public high school'
# Remaining titles to process: 11762
#
# Processing base title: 'senior manager, programmatic'
# Found 5 similar titles (threshold=50):
#   - 'senior program manager' (similarity score: 90) -> standardized to 'senior manager, programmatic'
#   - 'senior it program manager' (similarity score: 85) -> standardized to 'senior manager, programmatic'
#   - 'senior research program manager' (similarity score: 83) -> standardized to 'senior manager, programmatic'
#   - 'sr programming manager' (similarity score: 82) -> standardized to 'senior manager, programmatic'
#   - 'senior programmatic associate' (similarity score: 82) -> standardized to 'senior manager, programmatic'
# Remaining titles to process: 11756
#
# Processing base title: 'managed services sales coordinator'
# Found 5 similar titles (threshold=50):
#   - 'gallery services coordinator' (similarity score: 81) -> standardized to 'managed services sales coordinator'
#   - 'legislative services coordinator' (similarity score: 76) -> standardized to 'managed services sales coordinator'
#   - 'services sales manager' (similarity score: 75) -> standardized to 'managed services sales coordinator'
#   - 'international services coordinator' (similarity score: 74) -> standardized to 'managed services sales coordinator'
#   - 'program services coordinator' (similarity score: 74) -> standardized to 'managed services sales coordinator'
# Remaining titles to process: 11750
#
# Processing base title: 'water resources engineer'
# Found 5 similar titles (threshold=50):
#   - 'water resources manager' (similarity score: 85) -> standardized to 'water resources engineer'
#   - 'associate water resources engineer' (similarity score: 83) -> standardized to 'water resources engineer'
#   - 'water resources director' (similarity score: 79) -> standardized to 'water resources engineer'
#   - 'sr process engineer' (similarity score: 74) -> standardized to 'water resources engineer'
#   - 'process engineer two' (similarity score: 73) -> standardized to 'water resources engineer'
# Remaining titles to process: 11744
#
# Processing base title: 'program officer'
# Found 5 similar titles (threshold=50):
#   - 'program office' (similarity score: 97) -> standardized to 'program officer'
#   - 'programme officer' (similarity score: 94) -> standardized to 'program officer'
#   - 'chief program officer' (similarity score: 83) -> standardized to 'program officer'
#   - 'senior program officer' (similarity score: 81) -> standardized to 'program officer'
#   - 'chief programs officer' (similarity score: 81) -> standardized to 'program officer'
# Remaining titles to process: 11738
#
# Processing base title: 'account supervisor'
# Found 5 similar titles (threshold=50):
#   - 'account supervisor- pr' (similarity score: 92) -> standardized to 'account supervisor'
#   - 'accounting supervisor' (similarity score: 92) -> standardized to 'account supervisor'
#   - 'senior account supervisor' (similarity score: 84) -> standardized to 'account supervisor'
#   - 'accounts payable supervisor' (similarity score: 80) -> standardized to 'account supervisor'
#   - 'copy supervisor' (similarity score: 79) -> standardized to 'account supervisor'
# Remaining titles to process: 11732
#
# Processing base title: 'legal secretary'
# Found 5 similar titles (threshold=50):
#   - 'college secretary' (similarity score: 81) -> standardized to 'legal secretary'
#   - 'medical secretary' (similarity score: 81) -> standardized to 'legal secretary'
#   - 'secretary 1' (similarity score: 77) -> standardized to 'legal secretary'
#   - 'legal secretaryparalegal' (similarity score: 77) -> standardized to 'legal secretary'
#   - 'secretary' (similarity score: 75) -> standardized to 'legal secretary'
# Remaining titles to process: 11726
#
# Processing base title: 'policy lead'
# Found 5 similar titles (threshold=50):
#   - 'policy advisor' (similarity score: 72) -> standardized to 'policy lead'
#   - 'policy adviser' (similarity score: 72) -> standardized to 'policy lead'
#   - 'project lead' (similarity score: 70) -> standardized to 'policy lead'
#   - 'quality project lead' (similarity score: 65) -> standardized to 'policy lead'
#   - 'policy analyst' (similarity score: 64) -> standardized to 'policy lead'
# Remaining titles to process: 11720
#
# Processing base title: 'coordinator'
# Found 5 similar titles (threshold=50):
#   - 'hr coordinator' (similarity score: 88) -> standardized to 'coordinator'
#   - 'coordinator ii' (similarity score: 88) -> standardized to 'coordinator'
#   - 'qa coordinator' (similarity score: 88) -> standardized to 'coordinator'
#   - 'rn coordinator' (similarity score: 88) -> standardized to 'coordinator'
#   - 'sr. coordinator' (similarity score: 88) -> standardized to 'coordinator'
# Remaining titles to process: 11714
#
# Processing base title: 'senior advisor'
# Found 5 similar titles (threshold=50):
#   - 'senior it advisor' (similarity score: 90) -> standardized to 'senior advisor'
#   - 'senior hr advisor' (similarity score: 90) -> standardized to 'senior advisor'
#   - 'senior aditor' (similarity score: 89) -> standardized to 'senior advisor'
#   - 'senior auditor' (similarity score: 86) -> standardized to 'senior advisor'
#   - 'senior donor advisor' (similarity score: 82) -> standardized to 'senior advisor'
# Remaining titles to process: 11708
#
# Processing base title: 'safety director'
# Found 5 similar titles (threshold=50):
#   - 'sales director' (similarity score: 83) -> standardized to 'safety director'
#   - 'staff director' (similarity score: 83) -> standardized to 'safety director'
#   - 'director, sales' (similarity score: 83) -> standardized to 'safety director'
#   - 'strategy director' (similarity score: 81) -> standardized to 'safety director'
#   - 'director, strategy' (similarity score: 81) -> standardized to 'safety director'
# Remaining titles to process: 11702
#
# Processing base title: 'secondary school educator'
# Found 5 similar titles (threshold=50):
#   - 'senior health educator' (similarity score: 68) -> standardized to 'secondary school educator'
#   - 'school clerk-secretary' (similarity score: 68) -> standardized to 'secondary school educator'
#   - 'special education preschool teacher' (similarity score: 67) -> standardized to 'secondary school educator'
#   - 'secondary school teacher' (similarity score: 65) -> standardized to 'secondary school educator'
#   - 'secondary school english teacher' (similarity score: 63) -> standardized to 'secondary school educator'
# Remaining titles to process: 11696
#
# Processing base title: 'downstream process development research associate i'
# Found 5 similar titles (threshold=50):
#   - 'research and development associate' (similarity score: 71) -> standardized to 'downstream process development research associate i'
#   - 'associate director of resource development' (similarity score: 71) -> standardized to 'downstream process development research associate i'
#   - 'assistant director of development research' (similarity score: 71) -> standardized to 'downstream process development research associate i'
#   - 'post doctoral research associate' (similarity score: 70) -> standardized to 'downstream process development research associate i'
#   - 'associate director of development services' (similarity score: 69) -> standardized to 'downstream process development research associate i'
# Remaining titles to process: 11690
#
# Processing base title: 'research programmer'
# Found 5 similar titles (threshold=50):
#   - 'senior programmer' (similarity score: 78) -> standardized to 'research programmer'
#   - 'research program manager' (similarity score: 74) -> standardized to 'research programmer'
#   - 'prospect research' (similarity score: 72) -> standardized to 'research programmer'
#   - 'research leader' (similarity score: 71) -> standardized to 'research programmer'
#   - 'scientific programmer' (similarity score: 70) -> standardized to 'research programmer'
# Remaining titles to process: 11684
#
# Processing base title: 'manager, natural climate solutions development'
# Found 5 similar titles (threshold=50):
#   - 'associate manager original series development' (similarity score: 73) -> standardized to 'manager, natural climate solutions development'
#   - 'manager, development operations' (similarity score: 72) -> standardized to 'manager, natural climate solutions development'
#   - 'marketing and development manager' (similarity score: 69) -> standardized to 'manager, natural climate solutions development'
#   - 'talent development manager' (similarity score: 68) -> standardized to 'manager, natural climate solutions development'
#   - 'development operations associate' (similarity score: 68) -> standardized to 'manager, natural climate solutions development'
# Remaining titles to process: 11678
#
# Processing base title: 'ar manager'
# Found 5 similar titles (threshold=50):
#   - 'care manager' (similarity score: 91) -> standardized to 'ar manager'
#   - 'area manager' (similarity score: 91) -> standardized to 'ar manager'
#   - 'farm manager' (similarity score: 91) -> standardized to 'ar manager'
#   - 'hr manager' (similarity score: 90) -> standardized to 'ar manager'
#   - 'ma manager' (similarity score: 90) -> standardized to 'ar manager'
# Remaining titles to process: 11672
#
# Processing base title: 'technical specialist'
# Found 5 similar titles (threshold=50):
#   - 'sr. technical specialist' (similarity score: 93) -> standardized to 'technical specialist'
#   - 'technical specialist iii' (similarity score: 91) -> standardized to 'technical specialist'
#   - 'technical sales specialist' (similarity score: 87) -> standardized to 'technical specialist'
#   - 'senior technical specialist' (similarity score: 85) -> standardized to 'technical specialist'
#   - 'technical support specialist' (similarity score: 83) -> standardized to 'technical specialist'
# Remaining titles to process: 11666
#
# Processing base title: 'programming coordinator'
# Found 5 similar titles (threshold=50):
#   - 'programme coordinator' (similarity score: 91) -> standardized to 'programming coordinator'
#   - 'program coordinator' (similarity score: 90) -> standardized to 'programming coordinator'
#   - 'programs coordinator' (similarity score: 88) -> standardized to 'programming coordinator'
#   - 'digital programming coordinator' (similarity score: 85) -> standardized to 'programming coordinator'
#   - 'program coordinator ii' (similarity score: 84) -> standardized to 'programming coordinator'
# Remaining titles to process: 11660
#
# Processing base title: 'city research scientist ii'
# Found 5 similar titles (threshold=50):
#   - 'city research scientist' (similarity score: 94) -> standardized to 'city research scientist ii'
#   - 'research scientist ii' (similarity score: 89) -> standardized to 'city research scientist ii'
#   - 'research scientist i' (similarity score: 87) -> standardized to 'city research scientist ii'
#   - 'research scientist 2' (similarity score: 83) -> standardized to 'city research scientist ii'
#   - 'research scientist 3' (similarity score: 83) -> standardized to 'city research scientist ii'
# Remaining titles to process: 11654
#
# Processing base title: 'project engineer'
# Found 5 similar titles (threshold=50):
#   - 'sr. project engineer' (similarity score: 91) -> standardized to 'project engineer'
#   - 'sr project engineer' (similarity score: 91) -> standardized to 'project engineer'
#   - 'product engineer' (similarity score: 88) -> standardized to 'project engineer'
#   - 'project lead engineer' (similarity score: 86) -> standardized to 'project engineer'
#   - 'senior project engineer' (similarity score: 82) -> standardized to 'project engineer'
# Remaining titles to process: 11648
#
# Processing base title: 'pricing analyst'
# Found 5 similar titles (threshold=50):
#   - 'purchasing analyst' (similarity score: 85) -> standardized to 'pricing analyst'
#   - 'sourcing analyst' (similarity score: 84) -> standardized to 'pricing analyst'
#   - 'reporting analyst' (similarity score: 81) -> standardized to 'pricing analyst'
#   - 'principal analyst' (similarity score: 81) -> standardized to 'pricing analyst'
#   - 'packaging analyst' (similarity score: 81) -> standardized to 'pricing analyst'
# Remaining titles to process: 11642
#
# Processing base title: 'marketing coordinator'
# Found 5 similar titles (threshold=50):
#   - 'marketing coordinator ii' (similarity score: 93) -> standardized to 'marketing coordinator'
#   - 'marketing event coordinator' (similarity score: 88) -> standardized to 'marketing coordinator'
#   - 'sales  marketing coordinator' (similarity score: 88) -> standardized to 'marketing coordinator'
#   - 'senior marketing coordinator' (similarity score: 86) -> standardized to 'marketing coordinator'
#   - 'marketing coordinatoranalyst' (similarity score: 86) -> standardized to 'marketing coordinator'
# Remaining titles to process: 11636
#
# Processing base title: 'tech writer'
# Found 5 similar titles (threshold=50):
#   - 'technical writer' (similarity score: 81) -> standardized to 'tech writer'
#   - 'tv writer' (similarity score: 80) -> standardized to 'tech writer'
#   - 'hr writer' (similarity score: 80) -> standardized to 'tech writer'
#   - 'speechwriter' (similarity score: 78) -> standardized to 'tech writer'
#   - 'techical writer ii' (similarity score: 76) -> standardized to 'tech writer'
# Remaining titles to process: 11630
#
# Processing base title: 'supervisory archivist'
# Found 5 similar titles (threshold=50):
#   - 'archives supervisor' (similarity score: 90) -> standardized to 'supervisory archivist'
#   - 'senior archivist' (similarity score: 81) -> standardized to 'supervisory archivist'
#   - 'it supervisor' (similarity score: 76) -> standardized to 'supervisory archivist'
#   - 'shift supervisor' (similarity score: 76) -> standardized to 'supervisory archivist'
#   - 'supervisor hr specialist' (similarity score: 76) -> standardized to 'supervisory archivist'
# Remaining titles to process: 11624
#
# Processing base title: 'high school teacher at an independent school'
# Found 5 similar titles (threshold=50):
#   - 'online high school teacher' (similarity score: 66) -> standardized to 'high school teacher at an independent school'
#   - 'high school math teacher' (similarity score: 65) -> standardized to 'high school teacher at an independent school'
#   - 'high school history teacher' (similarity score: 65) -> standardized to 'high school teacher at an independent school'
#   - 'high school band teacher' (similarity score: 65) -> standardized to 'high school teacher at an independent school'
#   - 'high school spanish teacher' (similarity score: 62) -> standardized to 'high school teacher at an independent school'
# Remaining titles to process: 11618
#
# Processing base title: 'senior business analyst'
# Found 5 similar titles (threshold=50):
#   - 'senior it business analyst' (similarity score: 94) -> standardized to 'senior business analyst'
#   - 'junior business analyst' (similarity score: 91) -> standardized to 'senior business analyst'
#   - 'sr business analyst' (similarity score: 90) -> standardized to 'senior business analyst'
#   - 'sr. business analyst' (similarity score: 90) -> standardized to 'senior business analyst'
#   - 'business analyst i' (similarity score: 88) -> standardized to 'senior business analyst'
# Remaining titles to process: 11612
#
# Processing base title: 'special collections cataloger'
# Found 5 similar titles (threshold=50):
#   - 'special collections cataloging specialist' (similarity score: 77) -> standardized to 'special collections cataloger'
#   - 'special projects manager' (similarity score: 72) -> standardized to 'special collections cataloger'
#   - 'post closing corrections specialist' (similarity score: 69) -> standardized to 'special collections cataloger'
#   - 'head of special collections' (similarity score: 68) -> standardized to 'special collections cataloger'
#   - 'career education specialist' (similarity score: 68) -> standardized to 'special collections cataloger'
# Remaining titles to process: 11606
#
# Processing base title: 'teacher'
# Found 5 similar titles (threshold=50):
#   - 'art teacher' (similarity score: 78) -> standardized to 'teacher'
#   - 'esl teacher' (similarity score: 78) -> standardized to 'teacher'
#   - 'pls teacher' (similarity score: 78) -> standardized to 'teacher'
#   - 'ela teacher' (similarity score: 78) -> standardized to 'teacher'
#   - 'teacher ela' (similarity score: 78) -> standardized to 'teacher'
# Remaining titles to process: 11600
#
# Processing base title: 'graphic designer  webmaster'
# Found 5 similar titles (threshold=50):
#   - 'senior graphic designer' (similarity score: 82) -> standardized to 'graphic designer  webmaster'
#   - 'lead graphic designer' (similarity score: 81) -> standardized to 'graphic designer  webmaster'
#   - 'motion graphics designer' (similarity score: 76) -> standardized to 'graphic designer  webmaster'
#   - 'graphic design specialist' (similarity score: 75) -> standardized to 'graphic designer  webmaster'
#   - 'graphic designer print' (similarity score: 75) -> standardized to 'graphic designer  webmaster'
# Remaining titles to process: 11594
#
# Processing base title: 'senior ux designer'
# Found 5 similar titles (threshold=50):
#   - 'senior designer' (similarity score: 91) -> standardized to 'senior ux designer'
#   - 'sr ux designer' (similarity score: 88) -> standardized to 'senior ux designer'
#   - 'senior ux engineer' (similarity score: 83) -> standardized to 'senior ux designer'
#   - 'senior product designer ux' (similarity score: 82) -> standardized to 'senior ux designer'
# ...
# Remaining titles to process: 149
#
# Processing base title: 'managment fellow'
# Found 3 similar titles (threshold=50):
#   - 'photo lab manager' (similarity score: 55) -> standardized to 'managment fellow'
#   - 'gis team manager' (similarity score: 50) -> standardized to 'managment fellow'
#   - 'professional teaching fellow' (similarity score: 50) -> standardized to 'managment fellow'
# Remaining titles to process: 145
#
# Processing base title: 'head of cyber security'
# Found 1 similar titles (threshold=50):
#   - 'computer security incident responder' (similarity score: 55) -> standardized to 'head of cyber security'
# Remaining titles to process: 143
#
# Processing base title: 'highway engineer'
# Found 2 similar titles (threshold=50):
#   - 'staff sw engineer' (similarity score: 61) -> standardized to 'highway engineer'
#   - 'senior software engineer 250000' (similarity score: 51) -> standardized to 'highway engineer'
# Remaining titles to process: 140
#
# Processing base title: 'lead paediatric dietitian'
# Found 5 similar titles (threshold=50):
#   - 'detentions crew leader' (similarity score: 55) -> standardized to 'lead paediatric dietitian'
#   - 'paid media lead' (similarity score: 50) -> standardized to 'lead paediatric dietitian'
#   - 'masters-level clinician' (similarity score: 50) -> standardized to 'lead paediatric dietitian'
#   - 'medical director psychiatry' (similarity score: 50) -> standardized to 'lead paediatric dietitian'
#   - 'director of advising and career' (similarity score: 50) -> standardized to 'lead paediatric dietitian'
# Remaining titles to process: 134
#
# Processing base title: 'professeur dhistoire-géographie'
#   No matches found above threshold
#
# Processing base title: 'school certifying official'
#   No matches found above threshold
#
# Processing base title: 'executive business coach'
# Found 1 similar titles (threshold=50):
#   - 'business application expert' (similarity score: 51) -> standardized to 'executive business coach'
# Remaining titles to process: 130
#
# Processing base title: 'wissenschaftlicher mitarbeiter'
#   No matches found above threshold
#
# Processing base title: 'director of revenue cycle  ehr'
# Found 5 similar titles (threshold=50):
#   - 'director of the multicultural center' (similarity score: 55) -> standardized to 'director of revenue cycle  ehr'
#   - 'director, warehouse systems' (similarity score: 55) -> standardized to 'director of revenue cycle  ehr'
#   - 'director of global outreach' (similarity score: 54) -> standardized to 'director of revenue cycle  ehr'
#   - 'preschool program director' (similarity score: 51) -> standardized to 'director of revenue cycle  ehr'
#   - 'storyboard director' (similarity score: 50) -> standardized to 'director of revenue cycle  ehr'
# Remaining titles to process: 123
#
# Processing base title: '-'
#   No matches found above threshold
#
# Processing base title: 'junior risk manager'
# Found 4 similar titles (threshold=50):
#   - 'enterprise risk manager' (similarity score: 71) -> standardized to 'junior risk manager'
#   - 'import sourcing manager-apparel' (similarity score: 56) -> standardized to 'junior risk manager'
#   - 'product  implementation manager' (similarity score: 53) -> standardized to 'junior risk manager'
#   - 'weekend night manager' (similarity score: 50) -> standardized to 'junior risk manager'
# Remaining titles to process: 117
#
# Processing base title: 'amazon timekeeping hr admin'
#   No matches found above threshold
#
# Processing base title: 'health literacy  plain language content writer'
#   No matches found above threshold
#
# Processing base title: 'system security officer sso'
# Found 1 similar titles (threshold=50):
#   - 'senior embedded systems engineer' (similarity score: 51) -> standardized to 'system security officer sso'
# Remaining titles to process: 113
#
# Processing base title: 'vp, research'
# Found 2 similar titles (threshold=50):
#   - 'vp technology' (similarity score: 50) -> standardized to 'vp, research'
#   - 'devsecops' (similarity score: 50) -> standardized to 'vp, research'
# Remaining titles to process: 110
#
# Processing base title: 'scheduling officsd'
#   No matches found above threshold
#
# Processing base title: 'community impact lead'
#   No matches found above threshold
#
# Processing base title: 'medical science liaison'
#   No matches found above threshold
#
# Processing base title: 'best boy'
#   No matches found above threshold
#
# Processing base title: 'senior strategic business developer'
# Found 5 similar titles (threshold=50):
#   - 'group travel business development representative' (similarity score: 67) -> standardized to 'senior strategic business developer'
#   - 'senior devops and sre' (similarity score: 64) -> standardized to 'senior strategic business developer'
#   - 'mainframe cobol software developer iii' (similarity score: 52) -> standardized to 'senior strategic business developer'
#   - 'senior bulk trailer tech' (similarity score: 51) -> standardized to 'senior strategic business developer'
#   - 'technology systems developer' (similarity score: 51) -> standardized to 'senior strategic business developer'
# Remaining titles to process: 100
#
# Processing base title: 'curriculum consultantteacher leader'
#   No matches found above threshold
#
# Processing base title: 'gm'
# Found 1 similar titles (threshold=50):
#   - 'agm' (similarity score: 80) -> standardized to 'gm'
# Remaining titles to process: 97
#
# Processing base title: 'microbiologist officer'
# Found 1 similar titles (threshold=50):
#   - 'tier 2 copyright admin' (similarity score: 50) -> standardized to 'microbiologist officer'
# Remaining titles to process: 95
#
# Processing base title: 'law and policy advisor'
# Found 1 similar titles (threshold=50):
#   - 'strategy finance advisor' (similarity score: 57) -> standardized to 'law and policy advisor'
# Remaining titles to process: 93
#
# Processing base title: 'evp product'
# Found 1 similar titles (threshold=50):
#   - 'product innovations associate' (similarity score: 50) -> standardized to 'evp product'
# Remaining titles to process: 91
#
# Processing base title: 'vp of hr'
# Found 1 similar titles (threshold=50):
#   - 'for of hr' (similarity score: 59) -> standardized to 'vp of hr'
# Remaining titles to process: 89
#
# Processing base title: 'director congregational engagement and support'
# Found 1 similar titles (threshold=50):
#   - 'customer success manager - implementation manager and technical support' (similarity score: 52) -> standardized to 'director congregational engagement and support'
# Remaining titles to process: 87
#
# Processing base title: 'level 2 sys admin'
# Found 1 similar titles (threshold=50):
#   - 'hrbp  hris admin' (similarity score: 50) -> standardized to 'level 2 sys admin'
# Remaining titles to process: 85
#
# Processing base title: 'economic development planner'
# Found 2 similar titles (threshold=50):
#   - 'global planner iv' (similarity score: 53) -> standardized to 'economic development planner'
#   - 'urban forestersenior planner' (similarity score: 50) -> standardized to 'economic development planner'
# Remaining titles to process: 82
#
# Processing base title: 'lead elementary computer science teachermentor'
#   No matches found above threshold
#
# Processing base title: 'title support team supervisor'
# Found 2 similar titles (threshold=50):
#   - 'peer support worker' (similarity score: 54) -> standardized to 'title support team supervisor'
#   - 'supervisor, surgeryanesthesia ehr module' (similarity score: 53) -> standardized to 'title support team supervisor'
# Remaining titles to process: 78
#
# Processing base title: 'human resource associate'
# Found 5 similar titles (threshold=50):
#   - 'manufacturing associate' (similarity score: 64) -> standardized to 'human resource associate'
#   - 'general warehouse associate 2' (similarity score: 64) -> standardized to 'human resource associate'
#   - 'fraud monitoring associate' (similarity score: 60) -> standardized to 'human resource associate'
#   - 'export documentation assistant' (similarity score: 56) -> standardized to 'human resource associate'
#   - 'cloud developeranalyst - associate' (similarity score: 54) -> standardized to 'human resource associate'
# Remaining titles to process: 72
#
# Processing base title: 'paralegal, trusts  estates'
#   No matches found above threshold
#
# Processing base title: 'director, advertising compliance and forms design'
# Found 1 similar titles (threshold=50):
#   - 'director of global quality assurance  compliance' (similarity score: 55) -> standardized to 'director, advertising compliance and forms design'
# Remaining titles to process: 69
#
# Processing base title: 'fuel hauler cdl'
#   No matches found above threshold
#
# Processing base title: 'outsourcing'
# Found 1 similar titles (threshold=50):
#   - 'networking pm' (similarity score: 50) -> standardized to 'outsourcing'
# Remaining titles to process: 66
#
# Processing base title: 'further education funding and data consultant'
#   No matches found above threshold
#
# Processing base title: 'creative awards manager'
#   No matches found above threshold
#
# Processing base title: '911 dispatcher'
#   No matches found above threshold
#
# Processing base title: 'discovery  resource management systems coordinator librarian iii'
#   No matches found above threshold
#
# Processing base title: 'phd'
#   No matches found above threshold
#
# Processing base title: 'trauma therapist'
#   No matches found above threshold
#
# Processing base title: '6th and 7th grade math teacher'
#   No matches found above threshold
#
# Processing base title: 'childrens pastor'
# Found 2 similar titles (threshold=50):
#   - 'child welfare specialist i' (similarity score: 52) -> standardized to 'childrens pastor'
#   - 'child welfare specialist iv' (similarity score: 51) -> standardized to 'childrens pastor'
# Remaining titles to process: 56
#
# Processing base title: 'data integrity'
# Found 2 similar titles (threshold=50):
#   - 'data  insights leads' (similarity score: 55) -> standardized to 'data integrity'
#   - 'dental hygienist' (similarity score: 53) -> standardized to 'data integrity'
# Remaining titles to process: 53
#
# Processing base title: 'auto liability representative 2'
#   No matches found above threshold
#
# Processing base title: 'mortgage originator'
#   No matches found above threshold
#
# Processing base title: 'sr document imaging rep'
#   No matches found above threshold
#
# Processing base title: 'no official title. do whatever needs to be done- i was hired as a bookeeper, now do estimatinf, projext management, schedulong'
#   No matches found above threshold
#
# Processing base title: 'msw'
# Found 1 similar titles (threshold=50):
#   - 'licsw' (similarity score: 50) -> standardized to 'msw'
# Remaining titles to process: 47
#
# Processing base title: 'senior architectural conservator'
#   No matches found above threshold
#
# Processing base title: 'jjj'
#   No matches found above threshold
#
# Processing base title: 'inbound sales'
#   No matches found above threshold
#
# Processing base title: 'rail engineering level 3 apprenticeship'
#   No matches found above threshold
#
# Processing base title: 'shipperreceiver'
#   No matches found above threshold
#
# Processing base title: 'parenting support worker'
# Found 1 similar titles (threshold=50):
#   - 'work placement tutor' (similarity score: 64) -> standardized to 'parenting support worker'
# Remaining titles to process: 40
#
# Processing base title: 'locum doctor'
#   No matches found above threshold
#
# Processing base title: 'health and wellness promoter'
# Found 1 similar titles (threshold=50):
#   - 'cx lead and scrum master' (similarity score: 50) -> standardized to 'health and wellness promoter'
# Remaining titles to process: 37
#
# Processing base title: 'junior buyer'
#   No matches found above threshold
#
# Processing base title: 'dog groomer'
#   No matches found above threshold
#
# Processing base title: 'adjunct'
#   No matches found above threshold
#
# Processing base title: 'senior knowledge and evidence lead'
#   No matches found above threshold
#
# Processing base title: 'payroll practitioner iii'
# Found 1 similar titles (threshold=50):
#   - 'hrpayroll specialist' (similarity score: 55) -> standardized to 'payroll practitioner iii'
# Remaining titles to process: 31
#
# Processing base title: 'obgyn'
#   No matches found above threshold
#
# Processing base title: 'us navy lieutenant commander'
#   No matches found above threshold
#
# Processing base title: 'dont have one. dont need one.'
#   No matches found above threshold
#
# Processing base title: 'noc technician tier 1'
#   No matches found above threshold
#
# Processing base title: 'program manager and weapons system  tactics sme'
# Found 1 similar titles (threshold=50):
#   - 'sr. manager, regulatory project management' (similarity score: 51) -> standardized to 'program manager and weapons system  tactics sme'
# Remaining titles to process: 25
#
# Processing base title: 'music copyist'
#   No matches found above threshold
#
# Processing base title: 'community programmes administrator'
#   No matches found above threshold
#
# Processing base title: 'health systems comptroller'
#   No matches found above threshold
#
# Processing base title: 'bilingual home visitor'
#   No matches found above threshold
#
# Processing base title: 'programme officer for latin america and the caribbean - research and advocacy'
#   No matches found above threshold
#
# Processing base title: 'senior hydroelectric power utility engineer'
#   No matches found above threshold
#
# Processing base title: 'elephant keeper'
#   No matches found above threshold
#
# Processing base title: 'hhh'
#   No matches found above threshold
#
# Processing base title: 'vice president of public relations'
#   No matches found above threshold
#
# Processing base title: 'project based escalated csr rep and specialized qa auditor'
#   No matches found above threshold
#
# Processing base title: 'wine steward'
#   No matches found above threshold
#
# Processing base title: 'wholesale planner'
#   No matches found above threshold
#
# Processing base title: 'gis team laader'
#   No matches found above threshold
#
# Processing base title: 'graduate research assistant - mechanical engineering - ga tech'
#   No matches found above threshold
#
# Processing base title: 'plumber'
# Found 1 similar titles (threshold=50):
#   - 'pumper' (similarity score: 77) -> standardized to 'plumber'
# Remaining titles to process: 9
#
# Processing base title: 'machinistroll grinder'
#   No matches found above threshold
#
# Processing base title: 'power trader'
#   No matches found above threshold
#
# Processing base title: 'scribe'
#   No matches found above threshold
#
# Processing base title: 'hotel maid'
#   No matches found above threshold
#
# Processing base title: 'helpdesk level 1'
#   No matches found above threshold
#
# Processing base title: 'revenue cycle billing  coding manager'
#   No matches found above threshold
#
# Processing base title: 'stocker'
#   No matches found above threshold
#
# Processing base title: '24 frame video playback'
#   No matches found above threshold
#
# Processing base title: 'online tutor'
#   No matches found above threshold
#
# Applying 11978 mappings to the dataset...
# Standardization complete!
# Total clusters formed: 2044
# Unique titles reduced from 12062 to 2128
#
# Sample of processed data:
#                                  Job title  \
# 0       research and instruction librarian
# 1  change  internal communications manager
# 2                     marketing specialist
# 3                          program manager
# 4                       accounting manager
# 5           scholarly publishing librarian
# 6                     publishing assistant
# 7                                librarian
# 8                          systems analyst
# 9                        senior accountant
#
#                     standardized_Job title
# 0       research and instruction librarian
# 1  change  internal communications manager
# 2                     marketing specialist
# 3                          program manager
# 4                       accounting manager
# 5           scholarly publishing librarian
# 6                     publishing assistant
# 7                                librarian
# 8                          systems analyst
# 9                        senior accountant

# %% [markdown]
# # Analyze Standardization Quality

# %%
"""
Additional analysis of standardization quality
"""
def analyze_standardization_quality(df):
    # Count occurrences of each standardized title
    title_counts = df['standardized_Job title'].value_counts()
    print("\nTop 10 standardized job titles:")
    print(title_counts.head(10))
    
    # Check for remaining inconsistencies
    potential_issues = title_counts[title_counts < 5].index
    print(f"\nNumber of titles appearing less than 5 times: {len(potential_issues)}")
    
    return title_counts

# Run quality analysis
title_counts = analyze_standardization_quality(processed_df)
# Out:
# Top 10 standardized job titles:
# software engineer           415
# project manager             321
# director                    280
# senior software engineer    254
# program manager             218
# executive assistant         213
# manager                     200
# teacher                     186
# librarian                   175
# product manager             161
# Name: standardized_Job title, dtype: int64
#
# Number of titles appearing less than 5 times: 162

# %% [markdown]
# #  Feature Construction for Adjusted Salary

# %%
"""
Define approximate conversion rates to USD as of April 2025 (update these as needed)
"""
conversion_rates = {
    'USD': 1.0,
    'GBP': 1.32,    # British Pound
    'CAD': 0.74,    # Canadian Dollar
    'EUR': 1.10,    # Euro
    'AUD': 0.67,    # Australian Dollar
    'SGD': 0.76,    # Singapore Dollar
    'PLN': 0.25,    # Polish Zloty
    'INR': 0.012,   # Indian Rupee
    'TRY': 0.029,   # Turkish Lira
    'NGN': 0.00061, # Nigerian Naira
    'COP': 0.00024, # Colombian Peso
    'INR': 0.012,    # Indian Rupee
    'DKK': 0.15     # Danish Kronor
}

"""
Function to clean and convert salary/bonus to float
"""
def clean_numeric(value):
    if pd.isna(value) or value == '':
        return 0.0
    try:
        # Remove commas and convert to float
        return float(str(value).replace(',', ''))
    except ValueError:
        return 0.0
    
"""
Clean the salary and bonus columns
"""
processed_df['Annual salary'] = processed_df['Annual salary'].apply(clean_numeric)
processed_df['Bonuses'].fillna(0, inplace=True)
processed_df['Bonuses'] = processed_df['Bonuses'].apply(clean_numeric)


"""
Determine currency and convert to USD
"""
def convert_to_usd(row):
    currency = row['Currency']
    salary = row['Annual salary']
    bonus = row['Bonuses']
    
    # If currency is "Other", try to get it from the "Other Currency" field
    if currency == 'Other':
        other_currency = str(row['Other Currency']).strip()
        # Map common "Other" currencies to our conversion rates
        currency_map = {
            'Singapore Dollara': 'SGD',
            'Singaporw': 'SGD',
            'PLN': 'PLN',
            'INR': 'INR',
            'TRY': 'TRY',
            'NGN': 'NGN',
            'COP': 'COP',
            'Rupees': 'Rupees'
        }
        currency = currency_map.get(other_currency, 'USD')
    
    # Get conversion rate (default to 1.0 if currency not found)
    rate = conversion_rates.get(currency, 1.0)
    
    # Convert total compensation (salary + bonus) to USD
    total_usd = (salary + bonus) * rate
    return total_usd

# %%
#Create the new "Salary in USD" column
processed_df['Salary in USD'] = processed_df.apply(convert_to_usd, axis=1)


# Apply Purchasing Power Parity Adjustment
ppp_factors = {'USD': 1.0,
               'GBP': 0.73,
               'CAD': 0.75,
               'EUR': 0.8,
               'AUD/NZD': 0.78,
               'CHF': 1.1,
               'ZAR': 0.25,
               'SEK': 0.84,
               'HKD': 0.85,
               'JPY': 0.62}

processed_df['Salary in USD (PPP Adjusted)'] = processed_df.apply(lambda row: row['Salary in USD'] / ppp_factors.get(row['Currency'], 0.50), axis=1)
print(processed_df[['Salary in USD', 'What country do you work in?', 'Salary in USD (PPP Adjusted)']])
# Out:
#        Salary in USD What country do you work in?  \
# 0            55000.0                United States
# 1            77352.0               United Kingdom
# 2            34000.0                           US
# 3            65000.0                          USA
# 4            67000.0                           US
# ...              ...                          ...
# 27935        25000.0                     Colombia
# 27936        55000.0               United States
# 27937        94000.0               United States
# 27938        64000.0                      denmark
# 27939       150000.0                           US
#
#        Salary in USD (PPP Adjusted)
# 0                      55000.000000
# 1                     105961.643836
# 2                      34000.000000
# 3                      65000.000000
# 4                      67000.000000
# ...                             ...
# 27935                  25000.000000
# 27936                  55000.000000
# 27937                  94000.000000
# 27938                  64000.000000
# 27939                 150000.000000
#
# [27940 rows x 3 columns]

# %% [markdown]
# # Outlier Handling

# %%
"""
Apply an upper bound to the adjusted salary values at the 95th percentile
"""

Q1 = processed_df['Salary in USD (PPP Adjusted)'].quantile(0.05)
Q3 = processed_df['Salary in USD (PPP Adjusted)'].quantile(0.95)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR
processed_df['Salary in USD (Capped)'] = processed_df['Salary in USD (PPP Adjusted)'].clip(upper=upper_bound)

max_salary_usd = processed_df['Salary in USD (PPP Adjusted)'].max()
max_salary_usd_capped = processed_df['Salary in USD (Capped)'].max()

print(f"Maximum Uncapped Salary in USD': {max_salary_usd}")
print(f"Maximum Capped Salary in USD': {max_salary_usd_capped}")
# Out:
# Maximum Uncapped Salary in USD': 1980000000.0
# Maximum Capped Salary in USD': 517900.0

# %% [markdown]
# # Feature Aggregation for Location related Features

# %%
"""
Standardize country names
"""
def standardize_country(country):
    # Dictionary mapping variations of United States to 'USA'
    us_variations = {
        'USA': 'USA',
        'US': 'USA',
        'United States': 'USA',
        'United Status': 'USA',
        'America': 'USA',
        'U.S.': 'USA',
        'U.S.A.': 'USA',
        'Usa': 'USA',
        'us': 'USA',
        'united states': 'USA'
    }
    # Return 'USA' if the country matches a variation, otherwise return the original country
    return us_variations.get(str(country).strip(), country)

"""
Aggregates location data into a single feature.
"""
def combine_location(row, country_col, state_col, city_col, us_country_value='USA'):
    country = row[country_col]
    state = row[state_col]
    city = row[city_col]
    
    # For US locations, include state if available
    if country == us_country_value and pd.notna(state) and pd.notna(city):
        return f"{country}-{state}-{city}"
    # For non-US locations or missing state/city, omit state
    elif pd.notna(city):
        return f"{country}-{city}"
    # Fallback if city is missing
    return country

# %%
"""
Apply Feature Aggregation
"""

# Standardize the country names
processed_df['What country do you work in?'] = processed_df['What country do you work in?'].apply(standardize_country)

# Apply the function to create the new 'Location' column
processed_df['Location'] = processed_df.apply(
    lambda row: combine_location(
        row,
        country_col='What country do you work in?',
        state_col="If you're in the U.S., what state do you work in?",
        city_col='What city do you work in?',
        us_country_value='USA'
    ),
    axis=1
)

# Display the first few rows of the result
print("\nFirst 10 rows with the new 'Location' column:")
print(processed_df[[
    'What country do you work in?',
    "If you're in the U.S., what state do you work in?",
    'What city do you work in?',
    'Location'
]].head(10))
# Out:
# First 10 rows with the new 'Location' column:
#   What country do you work in?  \
# 0                          USA
# 1               United Kingdom
# 2                          USA
# 3                          USA
# 4                          USA
# 5                          USA
# 6                          USA
# 7                          USA
# 8                          USA
# 9                          USA
#
#   If you're in the U.S., what state do you work in? What city do you work in?  \
# 0                                     Massachusetts                    Boston
# 1                                               NaN                 Cambridge
# 2                                         Tennessee               Chattanooga
# 3                                         Wisconsin                 Milwaukee
# 4                                    South Carolina                Greenville
# 5                                     New Hampshire                   Hanover
# 6                                    South Carolina                  Columbia
# 7                                           Arizona                      Yuma
# 8                                          Missouri                 St. Louis
# 9                                           Florida                Palm Coast
#
#                         Location
# 0       USA-Massachusetts-Boston
# 1       United Kingdom-Cambridge
# 2      USA-Tennessee-Chattanooga
# 3        USA-Wisconsin-Milwaukee
# 4  USA-South Carolina-Greenville
# 5      USA-New Hampshire-Hanover
# 6    USA-South Carolina-Columbia
# 7               USA-Arizona-Yuma
# 8         USA-Missouri-St. Louis
# 9         USA-Florida-Palm Coast

# %%
# Save the updated dataset to a new CSV file
processed_df.to_csv('processed_dataset.csv', index=False)
